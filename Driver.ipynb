# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd
from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
import imutils
import dlib

# %%
# !wget https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/driver_drowsiness_detection_modified.zip
# !unzip -qo driver_drowsiness_detection_modified.zip
# Out:
# --2023-08-10 20:03:27--  https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/driver_drowsiness_detection_modified.zip
# Resolving cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)... 52.219.156.195, 52.219.160.103, 52.219.158.111, ...
# Connecting to cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)|52.219.156.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 127436131 (122M) [application/x-zip-compressed]
# Saving to: ‘driver_drowsiness_detection_modified.zip’
#
# driver_drowsiness_d 100%[===================>] 121.53M  12.7MB/s    in 11s
#
# 2023-08-10 20:03:40 (10.6 MB/s) - ‘driver_drowsiness_detection_modified.zip’ saved [127436131/127436131]

# %%
data = np.load('driver_drowsiness_detection/dataset_compressed.npz', allow_pickle=True)
X = data['arr_0']
Y = data['arr_1']

X = list(X)
Y = list(Y)
print(len(X))
print(len(Y))
# Out:
# 1452
# 1452

# %%
for i in range(len(X)):
    img = X[i]
    img = cv2.resize(img, (32, 32))
    X[i] = img

print(len(X))
print(X[0].shape)
# Out:
# 1452
# (32, 32, 3)

# %%
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)
print(Y.shape)
print(Y[0])
print(set(Y))
# Out:
# (1452,)
# 0
# {0, 1}

# %%
X = np.array(X)
Y = np.array(Y)
print(X.shape)
print(Y.shape)
# Out:
# (1452, 32, 32, 3)
# (1452,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1161, 32, 32, 3)
# (1161,)
# (291, 32, 32, 3)
# (291,)
# (1161, 32, 32, 3)
# (1161, 2)
# (291, 32, 32, 3)
# (291, 2)

# %%
figure1 = plt.figure(figsize=(5, 5))
idx_closed = np.where(Y==0)
img_closed = X[idx_closed[0][0]]
plt.imshow(img_closed)
plt.title('Image of Closed Eye representing Driver is sleeping')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_open = np.where(Y==1)
img_open = X[idx_open[0][0]]
plt.imshow(img_open)
plt.title('Image of Open Eye representing Driver is not sleeping')
plt.axis('off')
plt.show()

# %%
def driver_drowsiness_detection_model(input_shape=(32, 32, 3)):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv1', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv2', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv5', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv6', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv7', activation='relu',
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))


    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer=glorot_uniform(seed=0), name='fc3'))

    optimizer = Adam(0.0001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= driver_drowsiness_detection_model(input_shape=(32, 32, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 8, 8, 64)          36928
#
#  batch_normalization_3 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  conv5 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_4 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  conv6 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_5 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  conv7 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_6 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 4, 4, 64)          0
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  fc1 (Dense)                 (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  fc2 (Dense)                 (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  fc3 (Dense)                 (None, 2)                 258
#
# =================================================================
# Total params: 227,554
# Trainable params: 226,786
# Non-trainable params: 768
# _________________________________________________________________

# %%
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.2, horizontal_flip=True)
hist = model.fit(aug.flow(X_train, Y_train, batch_size=128), batch_size=128, epochs=200, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# 10/10 [==============================] - 13s 762ms/step - loss: 1.3292 - accuracy: 0.5340 - val_loss: 0.7021 - val_accuracy: 0.5155
# Epoch 2/200
# 10/10 [==============================] - 10s 930ms/step - loss: 1.2778 - accuracy: 0.5366 - val_loss: 0.6772 - val_accuracy: 0.5223
# Epoch 3/200
# 10/10 [==============================] - 9s 873ms/step - loss: 1.0632 - accuracy: 0.5556 - val_loss: 0.6410 - val_accuracy: 0.5876
# Epoch 4/200
# 10/10 [==============================] - 8s 792ms/step - loss: 0.9618 - accuracy: 0.5952 - val_loss: 0.6219 - val_accuracy: 0.6632
# Epoch 5/200
# 10/10 [==============================] - 7s 678ms/step - loss: 0.9031 - accuracy: 0.6064 - val_loss: 0.6168 - val_accuracy: 0.7113
# Epoch 6/200
# 10/10 [==============================] - 8s 862ms/step - loss: 0.8544 - accuracy: 0.6115 - val_loss: 0.6145 - val_accuracy: 0.7182
# Epoch 7/200
# 10/10 [==============================] - 7s 688ms/step - loss: 0.7992 - accuracy: 0.6357 - val_loss: 0.6088 - val_accuracy: 0.7079
# Epoch 8/200
# 10/10 [==============================] - 8s 863ms/step - loss: 0.7829 - accuracy: 0.6107 - val_loss: 0.6016 - val_accuracy: 0.6907
# Epoch 9/200
# 10/10 [==============================] - 8s 830ms/step - loss: 0.7022 - accuracy: 0.6486 - val_loss: 0.5968 - val_accuracy: 0.6907
# Epoch 10/200
# 10/10 [==============================] - 7s 696ms/step - loss: 0.7274 - accuracy: 0.6563 - val_loss: 0.5910 - val_accuracy: 0.6804
# Epoch 11/200
# 10/10 [==============================] - 7s 679ms/step - loss: 0.6993 - accuracy: 0.6606 - val_loss: 0.5815 - val_accuracy: 0.6907
# Epoch 12/200
# 10/10 [==============================] - 8s 832ms/step - loss: 0.6824 - accuracy: 0.6761 - val_loss: 0.5717 - val_accuracy: 0.6907
# Epoch 13/200
# 10/10 [==============================] - 8s 828ms/step - loss: 0.6396 - accuracy: 0.6736 - val_loss: 0.5624 - val_accuracy: 0.6976
# Epoch 14/200
# 10/10 [==============================] - 7s 678ms/step - loss: 0.7332 - accuracy: 0.6581 - val_loss: 0.5486 - val_accuracy: 0.7285
# Epoch 15/200
# 10/10 [==============================] - 7s 678ms/step - loss: 0.6469 - accuracy: 0.6744 - val_loss: 0.5324 - val_accuracy: 0.7595
# Epoch 16/200
# 10/10 [==============================] - 7s 672ms/step - loss: 0.6391 - accuracy: 0.6994 - val_loss: 0.5207 - val_accuracy: 0.7663
# Epoch 17/200
# 10/10 [==============================] - 8s 779ms/step - loss: 0.6167 - accuracy: 0.6960 - val_loss: 0.5097 - val_accuracy: 0.7698
# Epoch 18/200
# 10/10 [==============================] - 8s 814ms/step - loss: 0.5989 - accuracy: 0.7071 - val_loss: 0.4970 - val_accuracy: 0.7698
# Epoch 19/200
# 10/10 [==============================] - 7s 662ms/step - loss: 0.5875 - accuracy: 0.7046 - val_loss: 0.4850 - val_accuracy: 0.7869
# Epoch 20/200
# 10/10 [==============================] - 9s 853ms/step - loss: 0.5675 - accuracy: 0.7304 - val_loss: 0.4732 - val_accuracy: 0.7973
# Epoch 21/200
# 10/10 [==============================] - 8s 881ms/step - loss: 0.5660 - accuracy: 0.7364 - val_loss: 0.4592 - val_accuracy: 0.8144
# Epoch 22/200
# 10/10 [==============================] - 7s 653ms/step - loss: 0.5526 - accuracy: 0.7459 - val_loss: 0.4467 - val_accuracy: 0.8213
# Epoch 23/200
# 10/10 [==============================] - 8s 806ms/step - loss: 0.5167 - accuracy: 0.7433 - val_loss: 0.4354 - val_accuracy: 0.8247
# Epoch 24/200
# 10/10 [==============================] - 8s 814ms/step - loss: 0.5565 - accuracy: 0.7450 - val_loss: 0.4197 - val_accuracy: 0.8282
# Epoch 25/200
# 10/10 [==============================] - 7s 697ms/step - loss: 0.5286 - accuracy: 0.7580 - val_loss: 0.4011 - val_accuracy: 0.8247
# Epoch 26/200
# 10/10 [==============================] - 7s 661ms/step - loss: 0.5191 - accuracy: 0.7554 - val_loss: 0.3856 - val_accuracy: 0.8316
# Epoch 27/200
# 10/10 [==============================] - 7s 659ms/step - loss: 0.5063 - accuracy: 0.7717 - val_loss: 0.3716 - val_accuracy: 0.8247
# Epoch 28/200
# 10/10 [==============================] - 7s 653ms/step - loss: 0.5363 - accuracy: 0.7778 - val_loss: 0.3576 - val_accuracy: 0.8351
# Epoch 29/200
# 10/10 [==============================] - 8s 801ms/step - loss: 0.4597 - accuracy: 0.7881 - val_loss: 0.3424 - val_accuracy: 0.8385
# Epoch 30/200
# 10/10 [==============================] - 8s 881ms/step - loss: 0.4501 - accuracy: 0.7916 - val_loss: 0.3262 - val_accuracy: 0.8660
# Epoch 31/200
# 10/10 [==============================] - 7s 692ms/step - loss: 0.4975 - accuracy: 0.7890 - val_loss: 0.3117 - val_accuracy: 0.8729
# Epoch 32/200
# 10/10 [==============================] - 8s 703ms/step - loss: 0.4556 - accuracy: 0.8079 - val_loss: 0.3000 - val_accuracy: 0.8694
# Epoch 33/200
# 10/10 [==============================] - 8s 812ms/step - loss: 0.4472 - accuracy: 0.7933 - val_loss: 0.2907 - val_accuracy: 0.8763
# Epoch 34/200
# 10/10 [==============================] - 7s 673ms/step - loss: 0.4286 - accuracy: 0.8165 - val_loss: 0.2809 - val_accuracy: 0.8694
# Epoch 35/200
# 10/10 [==============================] - 7s 668ms/step - loss: 0.4222 - accuracy: 0.8105 - val_loss: 0.2700 - val_accuracy: 0.8694
# Epoch 36/200
# 10/10 [==============================] - 8s 812ms/step - loss: 0.4407 - accuracy: 0.8217 - val_loss: 0.2581 - val_accuracy: 0.8832
# Epoch 37/200
# 10/10 [==============================] - 7s 731ms/step - loss: 0.3862 - accuracy: 0.8320 - val_loss: 0.2457 - val_accuracy: 0.8866
# Epoch 38/200
# 10/10 [==============================] - 7s 662ms/step - loss: 0.3848 - accuracy: 0.8295 - val_loss: 0.2347 - val_accuracy: 0.8935
# Epoch 39/200
# 10/10 [==============================] - 8s 809ms/step - loss: 0.3828 - accuracy: 0.8519 - val_loss: 0.2262 - val_accuracy: 0.9003
# Epoch 40/200
# 10/10 [==============================] - 8s 834ms/step - loss: 0.3529 - accuracy: 0.8510 - val_loss: 0.2173 - val_accuracy: 0.9038
# Epoch 41/200
# 10/10 [==============================] - 9s 793ms/step - loss: 0.3248 - accuracy: 0.8613 - val_loss: 0.2117 - val_accuracy: 0.9072
# Epoch 42/200
# 10/10 [==============================] - 8s 807ms/step - loss: 0.3183 - accuracy: 0.8665 - val_loss: 0.2106 - val_accuracy: 0.8969
# Epoch 43/200
# 10/10 [==============================] - 7s 662ms/step - loss: 0.3324 - accuracy: 0.8630 - val_loss: 0.2057 - val_accuracy: 0.9003
# Epoch 44/200
# 10/10 [==============================] - 8s 816ms/step - loss: 0.3417 - accuracy: 0.8630 - val_loss: 0.1967 - val_accuracy: 0.9107
# Epoch 45/200
# 10/10 [==============================] - 8s 758ms/step - loss: 0.3394 - accuracy: 0.8665 - val_loss: 0.1872 - val_accuracy: 0.9210
# Epoch 46/200
# 10/10 [==============================] - 7s 654ms/step - loss: 0.3066 - accuracy: 0.8803 - val_loss: 0.1779 - val_accuracy: 0.9278
# Epoch 47/200
# 10/10 [==============================] - 8s 805ms/step - loss: 0.3101 - accuracy: 0.8742 - val_loss: 0.1702 - val_accuracy: 0.9244
# Epoch 48/200
# 10/10 [==============================] - 7s 663ms/step - loss: 0.2902 - accuracy: 0.8794 - val_loss: 0.1641 - val_accuracy: 0.9244
# Epoch 49/200
# 10/10 [==============================] - 7s 662ms/step - loss: 0.2861 - accuracy: 0.9001 - val_loss: 0.1546 - val_accuracy: 0.9347
# Epoch 50/200
# 10/10 [==============================] - 8s 819ms/step - loss: 0.2773 - accuracy: 0.8889 - val_loss: 0.1504 - val_accuracy: 0.9347
# Epoch 51/200
# 10/10 [==============================] - 7s 739ms/step - loss: 0.2818 - accuracy: 0.8906 - val_loss: 0.1483 - val_accuracy: 0.9381
# Epoch 52/200
# 10/10 [==============================] - 7s 668ms/step - loss: 0.2758 - accuracy: 0.9156 - val_loss: 0.1444 - val_accuracy: 0.9381
# Epoch 53/200
# 10/10 [==============================] - 8s 812ms/step - loss: 0.2522 - accuracy: 0.9147 - val_loss: 0.1423 - val_accuracy: 0.9381
# Epoch 54/200
# 10/10 [==============================] - 8s 760ms/step - loss: 0.2680 - accuracy: 0.9018 - val_loss: 0.1405 - val_accuracy: 0.9381
# Epoch 55/200
# 10/10 [==============================] - 7s 662ms/step - loss: 0.2406 - accuracy: 0.9053 - val_loss: 0.1339 - val_accuracy: 0.9485
# Epoch 56/200
# 10/10 [==============================] - 8s 811ms/step - loss: 0.2337 - accuracy: 0.9165 - val_loss: 0.1308 - val_accuracy: 0.9519
# Epoch 57/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.2224 - accuracy: 0.9199 - val_loss: 0.1291 - val_accuracy: 0.9519
# Epoch 58/200
# 10/10 [==============================] - 7s 673ms/step - loss: 0.2004 - accuracy: 0.9225 - val_loss: 0.1191 - val_accuracy: 0.9450
# Epoch 59/200
# 10/10 [==============================] - 8s 816ms/step - loss: 0.2164 - accuracy: 0.9190 - val_loss: 0.1171 - val_accuracy: 0.9485
# Epoch 60/200
# 10/10 [==============================] - 7s 746ms/step - loss: 0.2337 - accuracy: 0.9053 - val_loss: 0.1160 - val_accuracy: 0.9485
# Epoch 61/200
# 10/10 [==============================] - 7s 667ms/step - loss: 0.1962 - accuracy: 0.9320 - val_loss: 0.1149 - val_accuracy: 0.9553
# Epoch 62/200
# 10/10 [==============================] - 10s 971ms/step - loss: 0.1790 - accuracy: 0.9294 - val_loss: 0.1200 - val_accuracy: 0.9485
# Epoch 63/200
# 10/10 [==============================] - 8s 822ms/step - loss: 0.1751 - accuracy: 0.9320 - val_loss: 0.1135 - val_accuracy: 0.9553
# Epoch 64/200
# 10/10 [==============================] - 7s 664ms/step - loss: 0.1840 - accuracy: 0.9320 - val_loss: 0.1069 - val_accuracy: 0.9622
# Epoch 65/200
# 10/10 [==============================] - 8s 813ms/step - loss: 0.2385 - accuracy: 0.9147 - val_loss: 0.1062 - val_accuracy: 0.9691
# Epoch 66/200
# 10/10 [==============================] - 7s 670ms/step - loss: 0.1581 - accuracy: 0.9440 - val_loss: 0.1048 - val_accuracy: 0.9691
# Epoch 67/200
# 10/10 [==============================] - 8s 762ms/step - loss: 0.1975 - accuracy: 0.9216 - val_loss: 0.1022 - val_accuracy: 0.9656
# Epoch 68/200
# 10/10 [==============================] - 8s 845ms/step - loss: 0.1921 - accuracy: 0.9251 - val_loss: 0.0980 - val_accuracy: 0.9622
# Epoch 69/200
# 10/10 [==============================] - 7s 664ms/step - loss: 0.1850 - accuracy: 0.9328 - val_loss: 0.1004 - val_accuracy: 0.9588
# Epoch 70/200
# 10/10 [==============================] - 8s 890ms/step - loss: 0.1918 - accuracy: 0.9285 - val_loss: 0.0975 - val_accuracy: 0.9656
# Epoch 71/200
# 10/10 [==============================] - 8s 797ms/step - loss: 0.1766 - accuracy: 0.9328 - val_loss: 0.0914 - val_accuracy: 0.9691
# Epoch 72/200
# 10/10 [==============================] - 7s 669ms/step - loss: 0.1585 - accuracy: 0.9406 - val_loss: 0.0881 - val_accuracy: 0.9725
# Epoch 73/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.1580 - accuracy: 0.9432 - val_loss: 0.0874 - val_accuracy: 0.9691
# Epoch 74/200
# 10/10 [==============================] - 8s 811ms/step - loss: 0.1346 - accuracy: 0.9535 - val_loss: 0.0890 - val_accuracy: 0.9691
# Epoch 75/200
# 10/10 [==============================] - 8s 805ms/step - loss: 0.1674 - accuracy: 0.9406 - val_loss: 0.0952 - val_accuracy: 0.9622
# Epoch 76/200
# 10/10 [==============================] - 7s 665ms/step - loss: 0.1744 - accuracy: 0.9354 - val_loss: 0.0956 - val_accuracy: 0.9588
# Epoch 77/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.1555 - accuracy: 0.9449 - val_loss: 0.0914 - val_accuracy: 0.9622
# Epoch 78/200
# 10/10 [==============================] - 8s 817ms/step - loss: 0.1470 - accuracy: 0.9449 - val_loss: 0.0903 - val_accuracy: 0.9691
# Epoch 79/200
# 10/10 [==============================] - 8s 886ms/step - loss: 0.1349 - accuracy: 0.9578 - val_loss: 0.0961 - val_accuracy: 0.9588
# Epoch 80/200
# 10/10 [==============================] - 7s 667ms/step - loss: 0.1406 - accuracy: 0.9492 - val_loss: 0.0880 - val_accuracy: 0.9691
# Epoch 81/200
# 10/10 [==============================] - 7s 672ms/step - loss: 0.1673 - accuracy: 0.9500 - val_loss: 0.0863 - val_accuracy: 0.9725
# Epoch 82/200
# 10/10 [==============================] - 7s 674ms/step - loss: 0.1346 - accuracy: 0.9500 - val_loss: 0.0899 - val_accuracy: 0.9691
# Epoch 83/200
# 10/10 [==============================] - 9s 1s/step - loss: 0.1403 - accuracy: 0.9414 - val_loss: 0.0856 - val_accuracy: 0.9691
# Epoch 84/200
# 10/10 [==============================] - 8s 806ms/step - loss: 0.1323 - accuracy: 0.9578 - val_loss: 0.0838 - val_accuracy: 0.9691
# Epoch 85/200
# 10/10 [==============================] - 7s 672ms/step - loss: 0.1229 - accuracy: 0.9509 - val_loss: 0.0881 - val_accuracy: 0.9691
# Epoch 86/200
# 10/10 [==============================] - 8s 743ms/step - loss: 0.1376 - accuracy: 0.9552 - val_loss: 0.0896 - val_accuracy: 0.9656
# Epoch 87/200
# 10/10 [==============================] - 8s 822ms/step - loss: 0.1100 - accuracy: 0.9638 - val_loss: 0.0761 - val_accuracy: 0.9691
# Epoch 88/200
# 10/10 [==============================] - 8s 794ms/step - loss: 0.1300 - accuracy: 0.9475 - val_loss: 0.0785 - val_accuracy: 0.9622
# Epoch 89/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.1032 - accuracy: 0.9612 - val_loss: 0.0816 - val_accuracy: 0.9691
# Epoch 90/200
# 10/10 [==============================] - 8s 819ms/step - loss: 0.1193 - accuracy: 0.9612 - val_loss: 0.0774 - val_accuracy: 0.9759
# Epoch 91/200
# 10/10 [==============================] - 8s 813ms/step - loss: 0.1075 - accuracy: 0.9655 - val_loss: 0.0702 - val_accuracy: 0.9759
# Epoch 92/200
# 10/10 [==============================] - 7s 748ms/step - loss: 0.1026 - accuracy: 0.9612 - val_loss: 0.0822 - val_accuracy: 0.9691
# Epoch 93/200
# 10/10 [==============================] - 8s 885ms/step - loss: 0.1232 - accuracy: 0.9543 - val_loss: 0.0963 - val_accuracy: 0.9691
# Epoch 94/200
# 10/10 [==============================] - 7s 698ms/step - loss: 0.1053 - accuracy: 0.9612 - val_loss: 0.0798 - val_accuracy: 0.9725
# Epoch 95/200
# 10/10 [==============================] - 8s 739ms/step - loss: 0.1019 - accuracy: 0.9604 - val_loss: 0.0795 - val_accuracy: 0.9691
# Epoch 96/200
# 10/10 [==============================] - 8s 812ms/step - loss: 0.1071 - accuracy: 0.9664 - val_loss: 0.0900 - val_accuracy: 0.9725
# Epoch 97/200
# 10/10 [==============================] - 8s 880ms/step - loss: 0.1100 - accuracy: 0.9638 - val_loss: 0.0877 - val_accuracy: 0.9691
# Epoch 98/200
# 10/10 [==============================] - 7s 661ms/step - loss: 0.1176 - accuracy: 0.9664 - val_loss: 0.0709 - val_accuracy: 0.9725
# Epoch 99/200
# 10/10 [==============================] - 7s 661ms/step - loss: 0.1097 - accuracy: 0.9595 - val_loss: 0.0666 - val_accuracy: 0.9759
# Epoch 100/200
# 10/10 [==============================] - 8s 801ms/step - loss: 0.1125 - accuracy: 0.9621 - val_loss: 0.0778 - val_accuracy: 0.9725
# Epoch 101/200
# 10/10 [==============================] - 8s 759ms/step - loss: 0.0961 - accuracy: 0.9681 - val_loss: 0.0824 - val_accuracy: 0.9691
# Epoch 102/200
# 10/10 [==============================] - 7s 667ms/step - loss: 0.0927 - accuracy: 0.9664 - val_loss: 0.0740 - val_accuracy: 0.9622
# Epoch 103/200
# 10/10 [==============================] - 9s 947ms/step - loss: 0.0860 - accuracy: 0.9664 - val_loss: 0.0766 - val_accuracy: 0.9656
# Epoch 104/200
# 10/10 [==============================] - 8s 811ms/step - loss: 0.0894 - accuracy: 0.9673 - val_loss: 0.0825 - val_accuracy: 0.9656
# Epoch 105/200
# 10/10 [==============================] - 7s 668ms/step - loss: 0.1132 - accuracy: 0.9587 - val_loss: 0.0815 - val_accuracy: 0.9725
# Epoch 106/200
# 10/10 [==============================] - 7s 672ms/step - loss: 0.1055 - accuracy: 0.9638 - val_loss: 0.0626 - val_accuracy: 0.9759
# Epoch 107/200
# 10/10 [==============================] - 8s 810ms/step - loss: 0.0836 - accuracy: 0.9690 - val_loss: 0.0683 - val_accuracy: 0.9691
# Epoch 108/200
# 10/10 [==============================] - 8s 823ms/step - loss: 0.0778 - accuracy: 0.9742 - val_loss: 0.0717 - val_accuracy: 0.9691
# Epoch 109/200
# 10/10 [==============================] - 7s 739ms/step - loss: 0.0957 - accuracy: 0.9673 - val_loss: 0.0717 - val_accuracy: 0.9725
# Epoch 110/200
# 10/10 [==============================] - 8s 712ms/step - loss: 0.0888 - accuracy: 0.9733 - val_loss: 0.0580 - val_accuracy: 0.9656
# Epoch 111/200
# 10/10 [==============================] - 8s 814ms/step - loss: 0.0735 - accuracy: 0.9733 - val_loss: 0.0651 - val_accuracy: 0.9759
# Epoch 112/200
# 10/10 [==============================] - 8s 815ms/step - loss: 0.0745 - accuracy: 0.9655 - val_loss: 0.0490 - val_accuracy: 0.9725
# Epoch 113/200
# 10/10 [==============================] - 7s 670ms/step - loss: 0.1038 - accuracy: 0.9621 - val_loss: 0.0521 - val_accuracy: 0.9691
# Epoch 114/200
# 10/10 [==============================] - 7s 665ms/step - loss: 0.1035 - accuracy: 0.9621 - val_loss: 0.0764 - val_accuracy: 0.9759
# Epoch 115/200
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0949 - accuracy: 0.9612 - val_loss: 0.0672 - val_accuracy: 0.9759
# Epoch 116/200
# 10/10 [==============================] - 8s 740ms/step - loss: 0.0733 - accuracy: 0.9759 - val_loss: 0.0532 - val_accuracy: 0.9759
# Epoch 117/200
# 10/10 [==============================] - 8s 818ms/step - loss: 0.0887 - accuracy: 0.9724 - val_loss: 0.0413 - val_accuracy: 0.9794
# Epoch 118/200
# 10/10 [==============================] - 8s 812ms/step - loss: 0.0612 - accuracy: 0.9750 - val_loss: 0.0500 - val_accuracy: 0.9759
# Epoch 119/200
# 10/10 [==============================] - 7s 662ms/step - loss: 0.0746 - accuracy: 0.9707 - val_loss: 0.0720 - val_accuracy: 0.9759
# Epoch 120/200
# 10/10 [==============================] - 7s 779ms/step - loss: 0.0810 - accuracy: 0.9716 - val_loss: 0.0614 - val_accuracy: 0.9759
# Epoch 121/200
# 10/10 [==============================] - 8s 818ms/step - loss: 0.0867 - accuracy: 0.9690 - val_loss: 0.0567 - val_accuracy: 0.9691
# Epoch 122/200
# 10/10 [==============================] - 7s 720ms/step - loss: 0.0720 - accuracy: 0.9767 - val_loss: 0.0589 - val_accuracy: 0.9725
# Epoch 123/200
# 10/10 [==============================] - 9s 819ms/step - loss: 0.0718 - accuracy: 0.9776 - val_loss: 0.0666 - val_accuracy: 0.9759
# Epoch 124/200
# 10/10 [==============================] - 8s 817ms/step - loss: 0.0777 - accuracy: 0.9742 - val_loss: 0.0627 - val_accuracy: 0.9794
# Epoch 125/200
# 10/10 [==============================] - 7s 674ms/step - loss: 0.0641 - accuracy: 0.9793 - val_loss: 0.0557 - val_accuracy: 0.9794
# Epoch 126/200
# 10/10 [==============================] - 7s 661ms/step - loss: 0.0794 - accuracy: 0.9724 - val_loss: 0.0448 - val_accuracy: 0.9828
# Epoch 127/200
# 10/10 [==============================] - 8s 817ms/step - loss: 0.0729 - accuracy: 0.9690 - val_loss: 0.0494 - val_accuracy: 0.9828
# Epoch 128/200
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0654 - accuracy: 0.9707 - val_loss: 0.0578 - val_accuracy: 0.9759
# Epoch 129/200
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0460 - accuracy: 0.9845 - val_loss: 0.0625 - val_accuracy: 0.9759
# Epoch 130/200
# 10/10 [==============================] - 8s 818ms/step - loss: 0.0579 - accuracy: 0.9776 - val_loss: 0.0560 - val_accuracy: 0.9794
# Epoch 131/200
# 10/10 [==============================] - 7s 665ms/step - loss: 0.0653 - accuracy: 0.9767 - val_loss: 0.0662 - val_accuracy: 0.9794
# Epoch 132/200
# 10/10 [==============================] - 8s 813ms/step - loss: 0.0700 - accuracy: 0.9716 - val_loss: 0.1005 - val_accuracy: 0.9656
# Epoch 133/200
# 10/10 [==============================] - 8s 768ms/step - loss: 0.0954 - accuracy: 0.9742 - val_loss: 0.0893 - val_accuracy: 0.9691
# Epoch 134/200
# 10/10 [==============================] - 7s 663ms/step - loss: 0.0642 - accuracy: 0.9785 - val_loss: 0.0692 - val_accuracy: 0.9794
# Epoch 135/200
# 10/10 [==============================] - 8s 781ms/step - loss: 0.0703 - accuracy: 0.9742 - val_loss: 0.0615 - val_accuracy: 0.9828
# Epoch 136/200
# 10/10 [==============================] - 8s 813ms/step - loss: 0.0626 - accuracy: 0.9767 - val_loss: 0.0628 - val_accuracy: 0.9828
# Epoch 137/200
# 10/10 [==============================] - 8s 789ms/step - loss: 0.0556 - accuracy: 0.9828 - val_loss: 0.0712 - val_accuracy: 0.9759
# Epoch 138/200
# 10/10 [==============================] - 7s 667ms/step - loss: 0.0548 - accuracy: 0.9819 - val_loss: 0.0522 - val_accuracy: 0.9759
# Epoch 139/200
# 10/10 [==============================] - 8s 788ms/step - loss: 0.0896 - accuracy: 0.9655 - val_loss: 0.0562 - val_accuracy: 0.9794
# Epoch 140/200
# 10/10 [==============================] - 8s 806ms/step - loss: 0.0644 - accuracy: 0.9767 - val_loss: 0.0681 - val_accuracy: 0.9691
# Epoch 141/200
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0556 - accuracy: 0.9819 - val_loss: 0.0669 - val_accuracy: 0.9725
# Epoch 142/200
# 10/10 [==============================] - 7s 678ms/step - loss: 0.0742 - accuracy: 0.9785 - val_loss: 0.0633 - val_accuracy: 0.9759
# Epoch 143/200
# 10/10 [==============================] - 8s 748ms/step - loss: 0.0876 - accuracy: 0.9707 - val_loss: 0.0720 - val_accuracy: 0.9725
# Epoch 144/200
# 10/10 [==============================] - 8s 706ms/step - loss: 0.0562 - accuracy: 0.9802 - val_loss: 0.0701 - val_accuracy: 0.9725
# Epoch 145/200
# 10/10 [==============================] - 8s 811ms/step - loss: 0.0710 - accuracy: 0.9759 - val_loss: 0.0612 - val_accuracy: 0.9794
# Epoch 146/200
# 10/10 [==============================] - 7s 664ms/step - loss: 0.0968 - accuracy: 0.9673 - val_loss: 0.0512 - val_accuracy: 0.9759
# Epoch 147/200
# 10/10 [==============================] - 7s 675ms/step - loss: 0.0748 - accuracy: 0.9785 - val_loss: 0.0442 - val_accuracy: 0.9828
# Epoch 148/200
# 10/10 [==============================] - 7s 663ms/step - loss: 0.0542 - accuracy: 0.9811 - val_loss: 0.0435 - val_accuracy: 0.9828
# Epoch 149/200
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0573 - accuracy: 0.9785 - val_loss: 0.0433 - val_accuracy: 0.9828
# Epoch 150/200
# 10/10 [==============================] - 8s 814ms/step - loss: 0.0437 - accuracy: 0.9836 - val_loss: 0.0439 - val_accuracy: 0.9828
# Epoch 151/200
# 10/10 [==============================] - 7s 698ms/step - loss: 0.0602 - accuracy: 0.9811 - val_loss: 0.0545 - val_accuracy: 0.9725
# Epoch 152/200
# 10/10 [==============================] - 8s 705ms/step - loss: 0.0522 - accuracy: 0.9836 - val_loss: 0.0492 - val_accuracy: 0.9828
# Epoch 153/200
# 10/10 [==============================] - 8s 810ms/step - loss: 0.0661 - accuracy: 0.9802 - val_loss: 0.0400 - val_accuracy: 0.9794
# Epoch 154/200
# 10/10 [==============================] - 7s 675ms/step - loss: 0.0521 - accuracy: 0.9785 - val_loss: 0.0355 - val_accuracy: 0.9794
# Epoch 155/200
# 10/10 [==============================] - 8s 816ms/step - loss: 0.0579 - accuracy: 0.9767 - val_loss: 0.0535 - val_accuracy: 0.9828
# Epoch 156/200
# 10/10 [==============================] - 8s 812ms/step - loss: 0.0471 - accuracy: 0.9888 - val_loss: 0.0590 - val_accuracy: 0.9794
# Epoch 157/200
# 10/10 [==============================] - 7s 674ms/step - loss: 0.0667 - accuracy: 0.9759 - val_loss: 0.0728 - val_accuracy: 0.9759
# Epoch 158/200
# 10/10 [==============================] - 8s 807ms/step - loss: 0.0492 - accuracy: 0.9819 - val_loss: 0.0448 - val_accuracy: 0.9794
# Epoch 159/200
# 10/10 [==============================] - 8s 816ms/step - loss: 0.0360 - accuracy: 0.9879 - val_loss: 0.0393 - val_accuracy: 0.9828
# Epoch 160/200
# 10/10 [==============================] - 7s 665ms/step - loss: 0.0525 - accuracy: 0.9828 - val_loss: 0.0459 - val_accuracy: 0.9759
# Epoch 161/200
# 10/10 [==============================] - 8s 893ms/step - loss: 0.0287 - accuracy: 0.9897 - val_loss: 0.0504 - val_accuracy: 0.9759
# Epoch 162/200
# 10/10 [==============================] - 8s 759ms/step - loss: 0.0500 - accuracy: 0.9811 - val_loss: 0.0449 - val_accuracy: 0.9759
# Epoch 163/200
# 10/10 [==============================] - 9s 812ms/step - loss: 0.0365 - accuracy: 0.9897 - val_loss: 0.0495 - val_accuracy: 0.9759
# Epoch 164/200
# 10/10 [==============================] - 8s 813ms/step - loss: 0.0394 - accuracy: 0.9862 - val_loss: 0.0473 - val_accuracy: 0.9794
# Epoch 165/200
# 10/10 [==============================] - 8s 813ms/step - loss: 0.0426 - accuracy: 0.9836 - val_loss: 0.0488 - val_accuracy: 0.9863
# Epoch 166/200
# 10/10 [==============================] - 7s 719ms/step - loss: 0.0440 - accuracy: 0.9854 - val_loss: 0.0547 - val_accuracy: 0.9828
# Epoch 167/200
# 10/10 [==============================] - 7s 673ms/step - loss: 0.0442 - accuracy: 0.9871 - val_loss: 0.0731 - val_accuracy: 0.9759
# Epoch 168/200
# 10/10 [==============================] - 8s 818ms/step - loss: 0.0577 - accuracy: 0.9776 - val_loss: 0.0798 - val_accuracy: 0.9725
# Epoch 169/200
# 10/10 [==============================] - 7s 666ms/step - loss: 0.0355 - accuracy: 0.9871 - val_loss: 0.0673 - val_accuracy: 0.9725
# Epoch 170/200
# 10/10 [==============================] - 8s 817ms/step - loss: 0.0598 - accuracy: 0.9828 - val_loss: 0.0646 - val_accuracy: 0.9759
# Epoch 171/200
# 10/10 [==============================] - 7s 665ms/step - loss: 0.0364 - accuracy: 0.9879 - val_loss: 0.0605 - val_accuracy: 0.9794
# Epoch 172/200
# 10/10 [==============================] - 8s 756ms/step - loss: 0.0362 - accuracy: 0.9871 - val_loss: 0.0572 - val_accuracy: 0.9759
# Epoch 173/200
# 10/10 [==============================] - 8s 815ms/step - loss: 0.0367 - accuracy: 0.9871 - val_loss: 0.0481 - val_accuracy: 0.9828
# Epoch 174/200
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0362 - accuracy: 0.9888 - val_loss: 0.0498 - val_accuracy: 0.9759
# Epoch 175/200
# 10/10 [==============================] - 8s 812ms/step - loss: 0.0460 - accuracy: 0.9862 - val_loss: 0.0564 - val_accuracy: 0.9759
# Epoch 176/200
# 10/10 [==============================] - 8s 808ms/step - loss: 0.0301 - accuracy: 0.9879 - val_loss: 0.0563 - val_accuracy: 0.9759
# Epoch 177/200
# 10/10 [==============================] - 7s 670ms/step - loss: 0.0358 - accuracy: 0.9862 - val_loss: 0.0550 - val_accuracy: 0.9725
# Epoch 178/200
# 10/10 [==============================] - 8s 804ms/step - loss: 0.0328 - accuracy: 0.9888 - val_loss: 0.0559 - val_accuracy: 0.9691
# Epoch 179/200
# 10/10 [==============================] - 7s 674ms/step - loss: 0.0356 - accuracy: 0.9845 - val_loss: 0.0459 - val_accuracy: 0.9794
# Epoch 180/200
# 10/10 [==============================] - 7s 676ms/step - loss: 0.0393 - accuracy: 0.9871 - val_loss: 0.0392 - val_accuracy: 0.9794
# Epoch 181/200
# 10/10 [==============================] - 8s 812ms/step - loss: 0.0368 - accuracy: 0.9854 - val_loss: 0.0600 - val_accuracy: 0.9759
# Epoch 182/200
# 10/10 [==============================] - 7s 665ms/step - loss: 0.0310 - accuracy: 0.9888 - val_loss: 0.0535 - val_accuracy: 0.9759
# Epoch 183/200
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0365 - accuracy: 0.9879 - val_loss: 0.0414 - val_accuracy: 0.9828
# Epoch 184/200
# 10/10 [==============================] - 8s 889ms/step - loss: 0.0275 - accuracy: 0.9914 - val_loss: 0.0518 - val_accuracy: 0.9794
# Epoch 185/200
# 10/10 [==============================] - 8s 884ms/step - loss: 0.0313 - accuracy: 0.9922 - val_loss: 0.0505 - val_accuracy: 0.9828
# Epoch 186/200
# 10/10 [==============================] - 7s 667ms/step - loss: 0.0228 - accuracy: 0.9940 - val_loss: 0.0427 - val_accuracy: 0.9863
# Epoch 187/200
# 10/10 [==============================] - 8s 752ms/step - loss: 0.0393 - accuracy: 0.9879 - val_loss: 0.0458 - val_accuracy: 0.9794
# Epoch 188/200
# 10/10 [==============================] - 8s 811ms/step - loss: 0.0364 - accuracy: 0.9897 - val_loss: 0.0441 - val_accuracy: 0.9759
# Epoch 189/200
# 10/10 [==============================] - 8s 784ms/step - loss: 0.0377 - accuracy: 0.9879 - val_loss: 0.0523 - val_accuracy: 0.9759
# Epoch 190/200
# 10/10 [==============================] - 7s 674ms/step - loss: 0.0384 - accuracy: 0.9879 - val_loss: 0.0431 - val_accuracy: 0.9794
# Epoch 191/200
# 10/10 [==============================] - 8s 814ms/step - loss: 0.0392 - accuracy: 0.9871 - val_loss: 0.0758 - val_accuracy: 0.9691
# Epoch 192/200
# 10/10 [==============================] - 8s 765ms/step - loss: 0.0510 - accuracy: 0.9845 - val_loss: 0.0372 - val_accuracy: 0.9794
# Epoch 193/200
# 10/10 [==============================] - 7s 663ms/step - loss: 0.0459 - accuracy: 0.9802 - val_loss: 0.0405 - val_accuracy: 0.9828
# Epoch 194/200
# 10/10 [==============================] - 7s 674ms/step - loss: 0.0472 - accuracy: 0.9862 - val_loss: 0.0838 - val_accuracy: 0.9759
# Epoch 195/200
# 10/10 [==============================] - 7s 802ms/step - loss: 0.0320 - accuracy: 0.9888 - val_loss: 0.0695 - val_accuracy: 0.9759
# Epoch 196/200
# 10/10 [==============================] - 8s 815ms/step - loss: 0.0474 - accuracy: 0.9845 - val_loss: 0.0517 - val_accuracy: 0.9759
# Epoch 197/200
# 10/10 [==============================] - 7s 669ms/step - loss: 0.0413 - accuracy: 0.9888 - val_loss: 0.0502 - val_accuracy: 0.9725
# Epoch 198/200
# 10/10 [==============================] - 7s 667ms/step - loss: 0.0356 - accuracy: 0.9905 - val_loss: 0.0756 - val_accuracy: 0.9725
# Epoch 199/200
# 10/10 [==============================] - 8s 815ms/step - loss: 0.0340 - accuracy: 0.9879 - val_loss: 0.1006 - val_accuracy: 0.9588
# Epoch 200/200
# 10/10 [==============================] - 8s 771ms/step - loss: 0.0412 - accuracy: 0.9879 - val_loss: 0.0789 - val_accuracy: 0.9725

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
pred = model.evaluate(X_test, Y_test)
print(f'Test Set Accuracy: {pred[1]}')
print(f'Test Set Loss: {pred[0]}')
# Out:
# 10/10 [==============================] - 1s 47ms/step - loss: 0.0789 - accuracy: 0.9725
# Test Set Accuracy: 0.9725086092948914
# Test Set Loss: 0.07887206226587296

# %%
ypred = model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
Y_test_pred = np.argmax(Y_test, axis=1)
print(classification_report(Y_test_pred, ypred))
# Out:
# 10/10 [==============================] - 1s 46ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       141
#            1       0.97      0.97      0.97       150
#
#     accuracy                           0.97       291
#    macro avg       0.97      0.97      0.97       291
# weighted avg       0.97      0.97      0.97       291

# %%
matrix = confusion_matrix(Y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')
# Out:
# <Axes: >

# %%
model.save('Driver_Drowsiness_Detection.h5')

# %%
labels = ['Closed', 'Open']
img_closed1 = cv2.imread('driver_drowsiness_detection/closed_eye.jpg')
img_closed2 = cv2.imread('driver_drowsiness_detection/closed_eye2.jpg')
img_open1 = cv2.imread('driver_drowsiness_detection/open_eye.jpg')
img_open2 = cv2.imread('driver_drowsiness_detection/open_eye2.jpg')

img_closed1 = cv2.resize(img_closed1, (32, 32))
img_closed2 = cv2.resize(img_closed2, (32, 32))
img_open1 = cv2.resize(img_open1, (32, 32))
img_open2 = cv2.resize(img_open2, (32, 32))

img_closed1 = np.array(img_closed1)
img_closed2 = np.array(img_closed2)
img_open1 = np.array(img_open1)
img_open2 = np.array(img_open2)

img_closed1 = np.expand_dims(img_closed1, axis=0)
img_closed2 = np.expand_dims(img_closed2, axis=0)
img_open1 = np.expand_dims(img_open1, axis=0)
img_open2 = np.expand_dims(img_open2, axis=0)
ypred_closed1 = model.predict(img_closed1)
ypred_closed2 = model.predict(img_closed2)
ypred_open1 = model.predict(img_open1)
ypred_open2 = model.predict(img_open2)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
figure = plt.figure(figsize=(2, 2))
img_closed1 = np.squeeze(img_closed1, axis=0)
plt.imshow(img_closed1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_closed1[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_open1 = np.squeeze(img_open1, axis=0)
plt.imshow(img_open1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_open1[0], axis=0)]}')
plt.show()

# %%
def full_face_detection_pipeline(input_image_path):
    face_cascade = cv2.CascadeClassifier('driver_drowsiness_detection/haarcascade_frontalface_default.xml')
    eye_cascade = cv2.CascadeClassifier('driver_drowsiness_detection/haarcascade_eye.xml')
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor('driver_drowsiness_detection/shape_predictor_68_face_landmarks.dat')
    fa = FaceAligner(predictor, desiredFaceWidth=256)
    test_image = cv2.imread(input_image_path)
    test_image = imutils.resize(test_image, width=800)
    test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    rects = detector(test_image_gray, 2)
    for rect in rects:
        (x, y, w, h) = rect_to_bb(rect)
        faceOrig = imutils.resize(test_image[y:y+h, x:x+w], width=256)
        faceAligned = fa.align(test_image, test_image_gray, rect)
        faceAligned_gray = cv2.cvtColor(faceAligned, cv2.COLOR_BGR2GRAY)
        plt.imshow(faceAligned_gray)
        plt.axis('off')
        plt.title('Aligned Face')
        plt.show()
        eyes = eye_cascade.detectMultiScale(faceAligned_gray, 1.1, 4)
        predictions = []
        for (ex, ey, ew, eh) in eyes:
            eye = faceAligned[ey:ey+eh, ex:ex+ew]
#             cv2.rectangle(test_image, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 0, 255), 8)
            eye = cv2.resize(eye, (32, 32))
            eye = np.array(eye)
            eye = np.expand_dims(eye, axis=0)
            ypred = model.predict(eye)
            ypred = np.argmax(ypred[0], axis=0)
            predictions.append(ypred)
        if all(i==0 for i in predictions):
            cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 0, 255), 8)
            cv2.putText(test_image, 'Sleeping', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 0, 255), 3)
        else:
            cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 255, 0), 8)
            cv2.putText(test_image, 'Not Sleeping', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 0), 3)
    output_path = 'driver_drowsiness_detection/test_image_prediction.jpg'
    cv2.imwrite(output_path, test_image)
    return output_path
